# %%
df=spark.read.format('delta').load('dbfs:/FileStore/delta_payments')
df.write.format('delta').mode('overwrite').saveAsTable('payments_table')
schema_string = df._jdf.schema().treeString()
print(schema_string)
# Out:
# root
#  |-- payment_id: string (nullable = true)
#  |-- date: string (nullable = true)
#  |-- amount: string (nullable = true)
#  |-- rider_id: string (nullable = true)

# %%
df=spark.read.format('delta').load('dbfs:/FileStore/delta_trip')
df.write.format('delta').mode('overwrite').saveAsTable('delta_trip')
schema_string = df._jdf.schema().treeString()
print(schema_string)
# Out:
# root
#  |-- trip_id: string (nullable = true)
#  |-- rideable_id: string (nullable = true)
#  |-- started_at: string (nullable = true)
#  |-- ended_at: string (nullable = true)
#  |-- start_station_id: string (nullable = true)
#  |-- end_station_id: string (nullable = true)
#  |-- rider_id: string (nullable = true)

# %%
df=spark.read.format('delta').load('dbfs:/FileStore/delta_stations')
df.write.format('delta').mode('overwrite').saveAsTable('stations_table')
schema_string = df._jdf.schema().treeString()
print(schema_string)
# Out:
# root
#  |-- station_id: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- latitude: string (nullable = true)
#  |-- longitude: string (nullable = true)

# %%
df=spark.read.format('delta').load('dbfs:/FileStore/delta_riders')
df.write.format('delta').mode('overwrite').saveAsTable('riders_table')
schema_string = df._jdf.schema().treeString()
print(schema_string)
# Out:
# root
#  |-- rider_id: string (nullable = true)
#  |-- first: string (nullable = true)
#  |-- last: string (nullable = true)
#  |-- address: string (nullable = true)
#  |-- birthday: string (nullable = true)
#  |-- account_start_date: string (nullable = true)
#  |-- account_end_date: string (nullable = true)
#  |-- is_member: string (nullable = true)
